# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
from langchain import HuggingFaceHub
from langchain.prompts import PromptTemplate
from langchain import LLMChain

# %%
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])

# %%
llm_chain = LLMChain(prompt=prompt, 
                     llm=HuggingFaceHub(repo_id="google/flan-t5-xxl", 
                                        model_kwargs={"temperature":0.8, 
                                                      
                                                      "max_length":512}))

# %%
question = "What is the capital of France?"

print(llm_chain.run(question))
# Out:
# Paris is the capital of France. Paris is located in the Île-de-France

# %%
question = "What area is best for growing wine in France?"

print(llm_chain.run(question))
# Out:
# The best growing conditions for wine can be found in the Mediterranean region. Most of France is in the

# %%
question = "New Delhi is capital of which country?"

print(llm_chain.run(question))
# Out:
# New Delhi is the capital of India. India is a country in South Asia. The answer:

# %%
import gradio as gr

def get_answer(question: str) -> str:
    return llm_chain.run(question)

# Create a Gradio interface
iface = gr.Interface(
    fn=get_answer,                          
    inputs=gr.inputs.Textbox(label="Question"),   
    outputs=gr.outputs.Textbox(label="Answer")                              
)
# Run the Gradio app
iface.launch()
# Out:
# /var/folders/nr/vw6x134n6n922pgr8m9nr9t80000gn/T/ipykernel_3961/2130752309.py:9: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   inputs=gr.inputs.Textbox(label="Question"),
# /var/folders/nr/vw6x134n6n922pgr8m9nr9t80000gn/T/ipykernel_3961/2130752309.py:9: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Textbox(label="Question"),
# /var/folders/nr/vw6x134n6n922pgr8m9nr9t80000gn/T/ipykernel_3961/2130752309.py:9: GradioDeprecationWarning: `numeric` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Textbox(label="Question"),
# /var/folders/nr/vw6x134n6n922pgr8m9nr9t80000gn/T/ipykernel_3961/2130752309.py:10: GradioDeprecationWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   outputs=gr.outputs.Textbox(label="Answer")
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
